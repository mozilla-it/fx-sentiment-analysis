# %%
from support_functions import *
df = read_exist_output('Data/2017_10_16/output_py.xlsx')
words, freq = compute_keywords_freq(df['Translated Reviews'],viz = True)

# %%
df = measure_sentiments(df)
df
# Out:
#     Store   Source       Date Version    Emotion Rating  \
# 0     iOS   Appbot 2017-10-16     9.2  delighted      4
# 1     iOS   Appbot 2017-10-16     9.2        sad      2
# 2     iOS   Appbot 2017-10-16     9.2      happy      5
# 3     iOS   Appbot 2017-10-15     9.2                 2
# 4     iOS   Appbot 2017-10-15     9.2                 1
# 5     iOS   Appbot 2017-10-15     9.2        meh      4
# 6     iOS   Appbot 2017-10-15     9.2      happy      4
# 7     iOS   Appbot 2017-10-15     9.2        sad      1
# 8     iOS   Appbot 2017-10-15     9.2                 5
# 9     iOS   Appbot 2017-10-15     9.2                 4
# 10    iOS   Appbot 2017-10-14     8.3                 5
# 11    iOS   Appbot 2017-10-14     9.2      angry      1
# 12    iOS   Appbot 2017-10-14     9.0                 4
# 13    iOS   Appbot 2017-10-14     9.2      happy      4
# 14    iOS   Appbot 2017-10-14     9.2        meh      2
# 15    iOS   Appbot 2017-10-14     9.2                 3
# ...

# %%
sub_df = df[['Rating','Sentiment']].loc[df['Rating'] != '']

# %%
def histogram(data, x_label, y_label, title):
    _, ax = plt.subplots()
    ax.hist(data, color = '#539caf')
    ax.set_ylabel(y_label)
    ax.set_xlabel(x_label)
    ax.set_title(title)
